# %%
import zipfile
import os

zip_path = "Dataset.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Convolution2D,MaxPooling2D,Flatten
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import HTML
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
IMAGE_SIZE = 128
train_dir = "Dataset/train"
val_dir = "Dataset/test"

train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        horizontal_flip=True
)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(IMAGE_SIZE,IMAGE_SIZE),
        class_mode="sparse",
)
# Out:
# Found 3352 images belonging to 7 classes.

# %%
class_names = list(train_generator.class_indices.keys())
class_names
# Out:
# ['Audi',
#  'Hyundai Creta',
#  'Mahindra Scorpio',
#  'Rolls Royce',
#  'Swift',
#  'Tata Safari',
#  'Toyota Innova']

# %%
test_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        horizontal_flip=True)

test_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(IMAGE_SIZE,IMAGE_SIZE),
        class_mode="sparse"
)
# Out:
# Found 813 images belonging to 7 classes.

# %%
sz = 128

# Initializing the CNN
model = Sequential()

# First convolution layer and pooling
model.add(Convolution2D(32, (3, 3), input_shape=(sz, sz, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# Second convolution layer and pooling
model.add(Convolution2D(32, (3, 3), activation='relu'))
# input_shape is going to be the pooled feature maps from the previous convolution layer
model.add(MaxPooling2D(pool_size=(2, 2)))

# Flattening the layers
model.add(Flatten())

# Adding a fully connected layer
model.add(Dense(units=96, activation='relu'))
model.add(Dropout(0.40))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=7, activation='softmax')) # softmax for more than 2
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 28800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 96)             │     2,764,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,778,375 (10.60 MB)
#  Trainable params: 2,778,375 (10.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=50
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 75s 692ms/step - accuracy: 0.2440 - loss: 1.8923 - val_accuracy: 0.3961 - val_loss: 1.7241
# Epoch 2/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 73s 692ms/step - accuracy: 0.3596 - loss: 1.7153 - val_accuracy: 0.4539 - val_loss: 1.5531
# Epoch 3/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 77s 729ms/step - accuracy: 0.4437 - loss: 1.5335 - val_accuracy: 0.5141 - val_loss: 1.3667
# Epoch 4/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 77s 729ms/step - accuracy: 0.5131 - loss: 1.3655 - val_accuracy: 0.5449 - val_loss: 1.3147
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 72s 682ms/step - accuracy: 0.5535 - loss: 1.2364 - val_accuracy: 0.5818 - val_loss: 1.1796
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 74s 701ms/step - accuracy: 0.5917 - loss: 1.1475 - val_accuracy: 0.5941 - val_loss: 1.1276
# Epoch 7/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 75s 716ms/step - accuracy: 0.6362 - loss: 1.0197 - val_accuracy: 0.6027 - val_loss: 1.0753
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 75s 714ms/step - accuracy: 0.6548 - loss: 0.9855 - val_accuracy: 0.6347 - val_loss: 1.0272
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 80s 699ms/step - accuracy: 0.6748 - loss: 0.8824 - val_accuracy: 0.6212 - val_loss: 1.0741
# Epoch 10/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 73s 690ms/step - accuracy: 0.7004 - loss: 0.8569 - val_accuracy: 0.6728 - val_loss: 0.9658
# Epoch 11/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 74s 705ms/step - accuracy: 0.7225 - loss: 0.8004 - val_accuracy: 0.6654 - val_loss: 0.9618
# Epoch 12/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 676ms/step - accuracy: 0.7252 - loss: 0.7643 - val_accuracy: 0.6667 - val_loss: 1.0323
# Epoch 13/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 76s 718ms/step - accuracy: 0.7550 - loss: 0.6953 - val_accuracy: 0.6630 - val_loss: 1.0187
# Epoch 14/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 73s 694ms/step - accuracy: 0.7698 - loss: 0.6688 - val_accuracy: 0.6876 - val_loss: 0.9325
# Epoch 15/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 679ms/step - accuracy: 0.7734 - loss: 0.6382 - val_accuracy: 0.6716 - val_loss: 0.9822
# Epoch 16/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 73s 694ms/step - accuracy: 0.7762 - loss: 0.6350 - val_accuracy: 0.6950 - val_loss: 0.9468
# Epoch 17/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 76s 720ms/step - accuracy: 0.7765 - loss: 0.6225 - val_accuracy: 0.6937 - val_loss: 0.9758
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 676ms/step - accuracy: 0.7948 - loss: 0.5626 - val_accuracy: 0.7085 - val_loss: 0.9586
# Epoch 19/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 73s 693ms/step - accuracy: 0.8103 - loss: 0.5406 - val_accuracy: 0.6876 - val_loss: 0.9770
# Epoch 20/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 678ms/step - accuracy: 0.8244 - loss: 0.4959 - val_accuracy: 0.7097 - val_loss: 0.9561
# Epoch 21/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 73s 693ms/step - accuracy: 0.8384 - loss: 0.4572 - val_accuracy: 0.6925 - val_loss: 0.9792
# Epoch 22/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 673ms/step - accuracy: 0.8270 - loss: 0.5033 - val_accuracy: 0.7011 - val_loss: 0.9899
# Epoch 23/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 82s 678ms/step - accuracy: 0.8207 - loss: 0.4786 - val_accuracy: 0.7073 - val_loss: 0.9350
# Epoch 24/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 70s 666ms/step - accuracy: 0.8406 - loss: 0.4150 - val_accuracy: 0.7232 - val_loss: 0.9308
# Epoch 25/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 72s 688ms/step - accuracy: 0.8676 - loss: 0.3717 - val_accuracy: 0.7159 - val_loss: 0.9315
# Epoch 26/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 678ms/step - accuracy: 0.8377 - loss: 0.4228 - val_accuracy: 0.7085 - val_loss: 0.9184
# Epoch 27/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 72s 688ms/step - accuracy: 0.8570 - loss: 0.4162 - val_accuracy: 0.7196 - val_loss: 0.9675
# Epoch 28/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 75s 715ms/step - accuracy: 0.8630 - loss: 0.3994 - val_accuracy: 0.7269 - val_loss: 0.9515
# Epoch 29/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 79s 690ms/step - accuracy: 0.8576 - loss: 0.3798 - val_accuracy: 0.7134 - val_loss: 0.9978
# Epoch 30/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 678ms/step - accuracy: 0.8743 - loss: 0.3566 - val_accuracy: 0.7220 - val_loss: 1.0798
# Epoch 31/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 72s 690ms/step - accuracy: 0.8757 - loss: 0.3489 - val_accuracy: 0.7146 - val_loss: 1.0874
# Epoch 32/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 72s 681ms/step - accuracy: 0.8705 - loss: 0.3620 - val_accuracy: 0.7245 - val_loss: 1.0635
# Epoch 33/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 73s 692ms/step - accuracy: 0.8848 - loss: 0.3322 - val_accuracy: 0.7159 - val_loss: 1.1061
# Epoch 34/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 75s 714ms/step - accuracy: 0.8746 - loss: 0.3310 - val_accuracy: 0.7122 - val_loss: 1.0391
# Epoch 35/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 677ms/step - accuracy: 0.8950 - loss: 0.3103 - val_accuracy: 0.7294 - val_loss: 1.0150
# Epoch 36/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 86s 712ms/step - accuracy: 0.8972 - loss: 0.2962 - val_accuracy: 0.7220 - val_loss: 1.0619
# Epoch 37/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 679ms/step - accuracy: 0.8847 - loss: 0.3090 - val_accuracy: 0.7343 - val_loss: 1.1248
# Epoch 38/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 73s 691ms/step - accuracy: 0.8984 - loss: 0.2819 - val_accuracy: 0.7417 - val_loss: 1.0840
# Epoch 39/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 680ms/step - accuracy: 0.8843 - loss: 0.3021 - val_accuracy: 0.7220 - val_loss: 1.0677
# Epoch 40/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 73s 691ms/step - accuracy: 0.8954 - loss: 0.2942 - val_accuracy: 0.7306 - val_loss: 1.0606
# Epoch 41/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 678ms/step - accuracy: 0.9033 - loss: 0.2806 - val_accuracy: 0.7319 - val_loss: 1.0958
# Epoch 42/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 72s 689ms/step - accuracy: 0.8949 - loss: 0.3067 - val_accuracy: 0.7392 - val_loss: 1.1517
# Epoch 43/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 75s 715ms/step - accuracy: 0.9059 - loss: 0.2640 - val_accuracy: 0.7528 - val_loss: 1.1780
# Epoch 44/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 76s 722ms/step - accuracy: 0.9079 - loss: 0.2619 - val_accuracy: 0.7294 - val_loss: 1.1870
# Epoch 45/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 78s 687ms/step - accuracy: 0.9043 - loss: 0.2508 - val_accuracy: 0.7282 - val_loss: 1.2158
# Epoch 46/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 71s 676ms/step - accuracy: 0.9161 - loss: 0.2306 - val_accuracy: 0.7478 - val_loss: 1.2071
# Epoch 47/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 86s 713ms/step - accuracy: 0.9004 - loss: 0.2492 - val_accuracy: 0.7245 - val_loss: 1.1961
# Epoch 48/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 81s 770ms/step - accuracy: 0.9138 - loss: 0.2386 - val_accuracy: 0.7478 - val_loss: 1.1693
# Epoch 49/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 75s 710ms/step - accuracy: 0.9080 - loss: 0.2547 - val_accuracy: 0.7183 - val_loss: 1.4391
# Epoch 50/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 73s 694ms/step - accuracy: 0.9117 - loss: 0.2582 - val_accuracy: 0.7208 - val_loss: 1.3126

# %%
scores = model.evaluate(test_generator)
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.7212 - loss: 1.3072

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
type(history.history['loss'])
# Out:
# list

# %%
len(history.history['loss'])
# Out:
# 50

# %%
history.history['loss'][:5] # show loss for first 5 epochs
# Out:
# [1.8325425386428833,
#  1.6753007173538208,
#  1.5104765892028809,
#  1.3529846668243408,
#  1.2343584299087524]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
import matplotlib.pyplot as plt
EPOCHS = 50

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np

# Obtener las etiquetas verdaderas (ya están en formato entero con "sparse" en class_mode)
true_classes = test_generator.classes

# Predecir las clases con el modelo
predictions = model.predict(test_generator, verbose=1)

# Convertir las predicciones a clases discretas (índices)
predicted_classes = np.argmax(predictions, axis=1)

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(true_classes, predicted_classes)

# Crear un gráfico con seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())

# Configurar título y etiquetas
plt.title('Matriz de Confusión', fontsize=16)
plt.xlabel('Predicción', fontsize=14)
plt.ylabel('Real', fontsize=14)
plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 13s 455ms/step

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i])
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_generator:
    for i in range(6):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])

        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[int(labels[i])]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
    break
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
